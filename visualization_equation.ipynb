# %% [markdown]
# # Visualization of a linear equation y=3x+6
#
# ### Based on three scripts you have created, you need to call them in order in the Python notebook, and then you will see two datasets, x_dataset.csv and y_dataset.csv, which are stored to the disk.  Each dataset is the output data which is created from step1 and step2. Before step3, you need to have x and y data points to help you plot the graph of the equation y=3x+6. Complete the above steps, you will see the graph of final result.

# %% [markdown]
# ## Step 1: Call generate_input_x.py
# #### Generate 1000 random numbers over the range 0-100 and save them to the disk in the csv format which is x dataset (x_dataset.csv).

# %%
# %run generate_input_x.py

# %% [markdown]
# ## Step 2: Call generate_output_y.py
# #### Generate new numbers from the original 1000 which are from step 1 using the equation y=3x+6 and store them to the disk in the csv format which is y dataset (y_dataset.csv).

# %%
# %run generate_output_y.py

# %% [markdown]
# ## Step 3: Include matplotlib magic and call plot_equation.py
# #### Based on x and y datasets you already have created, you need to use them to plot scatter chart including all the data points of the equation y=3x+6 with all values of x and all values of y and save the graph of the result into the disk.

# %%
# %matplotlib inline
# %run plot_equation.py
